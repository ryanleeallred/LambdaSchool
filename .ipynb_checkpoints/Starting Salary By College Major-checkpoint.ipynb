# %% [markdown]
# ## Found this Kaggle dataset as a starting point for seeing which degrees have the highest starting salaries. Kind of interesting, but we're going to want more fine grained data about specific jobs.

# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

# %%
# Initial code for this analysis comes from here: 
# https://www.kaggle.com/cdelany7/exploration-of-college-salaries-by-major 

df1 = pd.read_csv('~/Desktop/college-salaries/degrees-that-pay-back.csv')

# %%
df1.head()
# Out:
#      Undergraduate Major Starting Median Salary Mid-Career Median Salary  \
# 0             Accounting             $46,000.00               $77,100.00
# 1  Aerospace Engineering             $57,700.00              $101,000.00
# 2            Agriculture             $42,600.00               $71,900.00
# 3           Anthropology             $36,800.00               $61,500.00
# 4           Architecture             $41,600.00               $76,800.00
#
#    Percent change from Starting to Mid-Career Salary  \
# 0                                               67.6
# 1                                               75.0
# 2                                               68.8
# 3                                               67.1
# 4                                               84.6
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $42,200.00                        $56,100.00
# 1                        $64,300.00                        $82,100.00
# 2                        $36,300.00                        $52,100.00
# 3                        $33,800.00                        $45,500.00
# 4                        $50,600.00                        $62,200.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                       $108,000.00                       $152,000.00
# 1                       $127,000.00                       $161,000.00
# 2                        $96,300.00                       $150,000.00
# 3                        $89,300.00                       $138,000.00
# 4                        $97,000.00                       $136,000.00

# %%
# rename columns
df1.columns = ['major','bgn_p50','mid_p50','delta_bgn_mid','mid_p10','mid_p25','mid_p75','mid_p90']
df1.head()
# Out:
#                    major     bgn_p50      mid_p50  delta_bgn_mid     mid_p10  \
# 0             Accounting  $46,000.00   $77,100.00           67.6  $42,200.00
# 1  Aerospace Engineering  $57,700.00  $101,000.00           75.0  $64,300.00
# 2            Agriculture  $42,600.00   $71,900.00           68.8  $36,300.00
# 3           Anthropology  $36,800.00   $61,500.00           67.1  $33,800.00
# 4           Architecture  $41,600.00   $76,800.00           84.6  $50,600.00
#
#       mid_p25      mid_p75      mid_p90
# 0  $56,100.00  $108,000.00  $152,000.00
# 1  $82,100.00  $127,000.00  $161,000.00
# 2  $52,100.00   $96,300.00  $150,000.00
# 3  $45,500.00   $89,300.00  $138,000.00
# 4  $62,200.00   $97,000.00  $136,000.00

# %%
#type(df1['bgn_p50'][1]) # Tells us that all of the dollar sign values are actually strings. 

# Remove Dollar signs and change these columns to numeric.
dollar_cols = ['bgn_p50','mid_p50','mid_p10','mid_p25','mid_p75','mid_p90']

for x in dollar_cols:
    df1[x] = df1[x].str.replace("$","")
    df1[x] = df1[x].str.replace(",","")
    df1[x] = pd.to_numeric(df1[x])

df1.head()
# Out:
#                    major  bgn_p50   mid_p50  delta_bgn_mid  mid_p10  mid_p25  \
# 0             Accounting  46000.0   77100.0           67.6  42200.0  56100.0
# 1  Aerospace Engineering  57700.0  101000.0           75.0  64300.0  82100.0
# 2            Agriculture  42600.0   71900.0           68.8  36300.0  52100.0
# 3           Anthropology  36800.0   61500.0           67.1  33800.0  45500.0
# 4           Architecture  41600.0   76800.0           84.6  50600.0  62200.0
#
#     mid_p75   mid_p90
# 0  108000.0  152000.0
# 1  127000.0  161000.0
# 2   96300.0  150000.0
# 3   89300.0  138000.0
# 4   97000.0  136000.0

# %%
# Mean Starting Salary
df1['bgn_p50'].mean()
# Out:
# 44310.0

# %%
# Median Starting Salary
df1['bgn_p50'].median()
# Out:
# 40850.0

# %%
# Descriptive Statistics for 
df1.describe()
# Out:
#             bgn_p50       mid_p50  delta_bgn_mid       mid_p10       mid_p25  \
# count     50.000000      50.00000      50.000000     50.000000     50.000000
# mean   44310.000000   74786.00000      69.274000  43408.000000  55988.000000
# std     9360.866217   16088.40386      17.909908  12000.779567  13936.951911
# min    34000.000000   52000.00000      23.400000  26700.000000  36500.000000
# 25%    37050.000000   60825.00000      59.125000  34825.000000  44975.000000
# 50%    40850.000000   72000.00000      67.800000  39400.000000  52450.000000
# 75%    49875.000000   88750.00000      82.425000  49850.000000  63700.000000
# max    74300.000000  107000.00000     103.500000  71900.000000  87300.000000
#
#              mid_p75        mid_p90
# count      50.000000      50.000000
# mean   102138.000000  142766.000000
# std     20636.789914   27851.249267
# min     70500.000000   96400.000000
# 25%     83275.000000  124250.000000
# 50%     99400.000000  145500.000000
# 75%    118750.000000  161750.000000
# max    145000.000000  210000.000000

# %%
# sort by median starting salary
df1.sort_values(by = 'bgn_p50', ascending = False, inplace=True)
df1.head()
# Out:
#                      major  bgn_p50   mid_p50  delta_bgn_mid  mid_p10  \
# 43     Physician Assistant  74300.0   91700.0           23.4  66400.0
# 8     Chemical Engineering  63200.0  107000.0           69.3  71900.0
# 12    Computer Engineering  61400.0  105000.0           71.0  66100.0
# 19  Electrical Engineering  60900.0  103000.0           69.1  69300.0
# 38  Mechanical Engineering  57900.0   93600.0           61.7  63700.0
#
#     mid_p25   mid_p75   mid_p90
# 43  75200.0  108000.0  124000.0
# 8   87300.0  143000.0  194000.0
# 12  84100.0  135000.0  162000.0
# 19  83800.0  130000.0  168000.0
# 38  76200.0  120000.0  163000.0

# %%
# Plot Median starting and Mid-Career Salaries

df2 = df1.sort_values(by = 'bgn_p50', ascending = False)
df2 = df2.reset_index()

fig = plt.figure(figsize=(8,12))

x = df2['bgn_p50']
y = len(df2.index) - df2.index
labels = df2['major']

plt.scatter(x, y, color='#2b5bde', label = 'Median Starting Salary')
plt.yticks(y, labels)

x3 = df2['mid_p50']
plt.scatter(x3, y, color='#54d45d', label = 'Median Mid Career Salary')

plt.xlabel('US $')
plt.ylabel('')
plt.title('% of Software Engineer Listings ')
plt.legend(loc=2) #move the legend
plt.show()

# %%
# Plot Mid-Career Salaries by Percentile

df2 = df1.sort_values(by = 'mid_p50', ascending = False)
df2 = df2.reset_index()

fig = plt.figure(figsize=(8,12))
matplotlib.rc('grid', alpha = .5, color = '#e3dfdf')   #color the grid lines
matplotlib.rc('axes', edgecolor = '#67746A')           #color the graph edge
#matplotlib.rcParams.update(matplotlib.rcParamsDefault)  #this will reset default params if you need

x = df2['bgn_p50']
y = len(df2.index) - df2.index + 1
labels = df2['major']

#plt.scatter(x, y, color='b', label = 'Median Starting Salary')
plt.yticks(y, labels)

x1 = df2['mid_p10']
plt.scatter(x1, y, color='#f7e9ad', label = '10th pct. Mid Career Salary')

x2 = df2['mid_p25']
plt.scatter(x2, y, color='#ecc833', label = '25th pct. Mid Career Salary')

x3 = df2['mid_p50']
plt.scatter(x3, y, color='#54d45d', label = 'Median Mid Career Salary')

x4 = df2['mid_p75']
plt.scatter(x4, y, color='#2b5bde', label = '75th pct. Mid Career Salary')

x5 = df2['mid_p90']
plt.scatter(x5, y, color='#a1b6f0', label = '90th pct. Mid Career Salary')

plt.xlabel('US Dollars')
plt.ylabel('')
plt.title('Salary Information by Major')
plt.legend(loc='upper right', bbox_to_anchor=(1.42,.98))

plt.grid(True) #turn grid on

plt.show()
